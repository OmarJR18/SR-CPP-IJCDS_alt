# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('ablation_results.csv')
print(df)
print(f"\nColumns: {list(df.columns)}")
print(f"Configs: {df['Config'].unique()}")
# Out:
#          Dataset         Config  Accuracy       F1  Leaves  Nodes  Depth  \
# 0   BanknoteAuth  SR-CCP (full)   0.98742  0.98727     8.4   15.8    5.2
# 1   BanknoteAuth       No Depth   0.98142  0.98127    12.6   24.2    5.4
# 2   BanknoteAuth     No Feature   0.96942  0.96927    22.0   43.0    8.4
# 3   BanknoteAuth   No Penalties   0.98688  0.98671    23.4   45.8    8.2
# 4   BreastCancer  SR-CCP (full)   0.94377  0.93960     3.2    5.4    3.0
# 5   BreastCancer       No Depth   0.92577  0.92168     6.2   11.4    4.2
# 6   BreastCancer     No Feature   0.93877  0.93462     5.2    9.4    3.6
# 7   BreastCancer   No Penalties   0.93149  0.92551    11.8   22.6    6.2
# 8   HeartDisease  SR-CCP (full)   0.79630  0.79203     6.0   11.0    4.4
# 9   HeartDisease       No Depth   0.74430  0.74031     6.2   11.4    4.6
# 10  HeartDisease     No Feature   0.76430  0.76020     6.6   12.2    4.4
# 11  HeartDisease   No Penalties   0.78519  0.78146    25.6   50.2    7.8
# 12    Ionosphere  SR-CCP (full)   0.91653  0.90618     3.4    5.8    3.4
# 13    Ionosphere       No Depth   0.90753  0.89728     6.4   11.8    5.4
# 14    Ionosphere     No Feature   0.90253  0.89234     8.0   15.0    6.2
# 15    Ionosphere   No Penalties   0.91167  0.90360    12.6   24.2    7.6
# 16           KC2  SR-CCP (full)   0.85060  0.77328     2.0    3.0    2.0
# 17           KC2       No Depth   0.84760  0.77055     2.4    3.8    2.4
# 18           KC2     No Feature   0.83860  0.76237     3.2    5.4    2.8
# 19           KC2   No Penalties   0.86015  0.77822    15.8   30.6    6.6
# 20    QSARBiodeg  SR-CCP (full)   0.85024  0.82896     5.8   10.6    4.4
# 21    QSARBiodeg       No Depth   0.82024  0.79971     9.8   18.6    5.2
# 22    QSARBiodeg     No Feature   0.83224  0.81141    23.8   46.6    9.0
# 23    QSARBiodeg   No Penalties   0.84834  0.82883    38.2   75.4   10.2
# 24      SpamBase  SR-CCP (full)   0.91784  0.91325     6.4   11.8    4.6
# 25      SpamBase       No Depth   0.90484  0.90032     9.4   17.8    6.0
# 26      SpamBase     No Feature   0.90984  0.90529    21.2   41.4    8.8
# 27      SpamBase   No Penalties   0.92154  0.91758    71.4  141.8   16.2
#
#     n_Features
# 0          3.0
# 1          3.0
# 2          4.0
# 3          4.0
# 4          2.2
# 5          4.6
# 6          4.0
# 7          7.8
# 8          4.0
# 9          3.8
# 10         4.4
# 11         9.8
# 12         2.4
# 13         4.8
# 14         5.8
# 15         9.4
# 16         1.0
# 17         1.4
# 18         2.2
# 19         6.8
# 20         4.6
# 21         6.6
# 22        14.4
# 23        18.8
# 24         5.2
# 25         8.0
# 26        13.8
# 27        30.2
#
# Columns: ['Dataset', 'Config', 'Accuracy', 'F1', 'Leaves', 'Nodes', 'Depth', 'n_Features']
# Configs: <StringArray>
# ['SR-CCP (full)', 'No Depth', 'No Feature', 'No Penalties']
# Length: 4, dtype: str

# %%
# --- Summary table ---
summary = df.groupby('Config')[['Accuracy', 'Leaves', 'Nodes', 'Depth', 'n_Features']].mean()
print(summary.round(4))
# Out:
#                Accuracy   Leaves    Nodes   Depth  n_Features
# Config
# No Depth         0.8760   7.5714  14.1429  4.7429      4.6000
# No Feature       0.8794  12.8571  24.7143  6.1714      6.9429
# No Penalties     0.8922  28.4000  55.8000  8.9714     12.4000
# SR-CCP (full)    0.8947   5.0286   9.0571  3.8571      3.2000

# %%
# --- Chart 1: Accuracy ---
plt.figure(figsize=(14, 6))
ax = sns.barplot(data=df, x='Dataset', y='Accuracy', hue='Config', palette='Set2', edgecolor='black')
plt.title('Ablation Study: Accuracy', fontsize=14)
plt.ylabel('Accuracy', fontsize=12)
plt.xlabel('Dataset', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.ylim(0, 1)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(title='Config', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# --- Chart 2: Tree complexity ---
fig, axes = plt.subplots(2, 2, figsize=(16, 10))
fig.suptitle('Ablation: Tree Complexity', fontsize=15, y=1.02)
for ax, col, title in zip(axes.flat, ['Leaves', 'Nodes', 'Depth', 'n_Features'],
                         ['Number of Leaves', 'Number of Nodes', 'Tree Depth', 'Features Used']):
    sns.barplot(data=df, x='Dataset', y=col, hue='Config', palette='Set2', edgecolor='black', ax=ax)
    ax.set_title(title, fontsize=13)
    ax.set_ylabel(title, fontsize=11)
    ax.set_xlabel('')
    ax.tick_params(axis='x', rotation=45)
    ax.grid(axis='y', linestyle='--', alpha=0.7)
    if ax != axes[0, 0]:
        ax.get_legend().remove()
axes[0, 0].legend(title='Config', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# --- Delta from full SR-CCP ---
full = df[df['Config'] == 'SR-CCP (full)'].set_index('Dataset')
print('DELTA vs SR-CCP (full)')
print('='*60)
for cfg in ['No Depth', 'No Feature', 'No Penalties']:
    partial = df[df['Config'] == cfg].set_index('Dataset')
    delta_acc = partial['Accuracy'] - full['Accuracy']
    delta_feat = partial['n_Features'] - full['n_Features']
    delta_leaves = partial['Leaves'] - full['Leaves']
    print(f"\n{cfg} vs SR-CCP:")
    print(f"  Mean ΔAccuracy: {delta_acc.mean():+.4f}")
    print(f"  Mean ΔFeatures: {delta_feat.mean():+.1f}")
    print(f"  Mean ΔLeaves:   {delta_leaves.mean():+.1f}")
# Out:
# DELTA vs SR-CCP (full)
# ============================================================
#
# No Depth vs SR-CCP:
#   Mean ΔAccuracy: -0.0187
#   Mean ΔFeatures: +1.4
#   Mean ΔLeaves:   +2.5
#
# No Feature vs SR-CCP:
#   Mean ΔAccuracy: -0.0153
#   Mean ΔFeatures: +3.7
#   Mean ΔLeaves:   +7.8
#
# No Penalties vs SR-CCP:
#   Mean ΔAccuracy: -0.0025
#   Mean ΔFeatures: +9.2
#   Mean ΔLeaves:   +23.4
